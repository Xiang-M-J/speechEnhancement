# %%
import numpy as np
import matplotlib.pyplot as plt

loss = np.load("loss/loss.npy", allow_pickle=True).tolist()
test_loss = np.load("test_loss.npy")
train_loss = loss['train_loss']
valid_loss = loss['valid_loss']

# %%
print(test_loss)
# Out:
# 0.03672067813861828

# %%
x = range(1,len(train_loss)+1)
plt.plot(x, train_loss, x, valid_loss)
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(["train loss", "valid loss"])
plt.savefig("images/loss.png")
plt.show()
