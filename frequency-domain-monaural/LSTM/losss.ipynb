# %%
import numpy as np
a = np.load("loss.npy", allow_pickle=True).tolist()
print(a)
# Out:
# {'train_loss': [0.3207972195641748, 0.2077318858483742, 0.15825694139147628, 0.1249565844648871, 0.11121549525394522, 0.09736191853880882, 0.09015296732300314, 0.08593077501603241, 0.0792181536041457, 0.07459152843160875, 0.07219377077859024, 0.06952428162611764, 0.06641787296996035, 0.06298508549044872, 0.06097218004408581, 0.057791067235942545, 0.05614721920855086, 0.05499626135389352, 0.05318905265423758, 0.051485535560240006, 0.05008382192202683, 0.04904717476717357, 0.0480262348621056, 0.04541784505006568, 0.04315965162782834, 0.04189938782104131, 0.041476267743213426, 0.03997830154438471, 0.03981222291316452, 0.0387069146630579, 0.03843941396294997, 0.03777134577775824, 0.03711657428407464, 0.03683712145891683, 0.03639069100649192, 0.035201929920706254, 0.034867489158079544, 0.03458636998487957, 0.033885596846712045, 0.032499957444338964, 0.03173143430773554, 0.03158815747191166, 0.030949355960534563, 0.03121530446705633, 0.03036624221452351, 0.030575965752760913, 0.02977120366
# ...

# %%
import matplotlib.pyplot as plt

for i in range(60):
    a['valid_loss'][i] = a['valid_loss'][i].cpu().numpy()

# %%
plt.plot(a['valid_loss'])

# %%
np.save("loss.npy", a)

# %%
a = np.load("loss.npy", allow_pickle=True).tolist()
